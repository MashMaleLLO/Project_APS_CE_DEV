# %% [markdown]
# <a href="https://colab.research.google.com/github/MashMaleLLO/Project_APS_CE_DEV/blob/master/nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U pandasql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.3.5)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from pandasql) (1.4.41)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandasql) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandasql) (1.15.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (4.12.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->pandasql) (1.1.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy->pandasql) (3.8.1)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26784 sha256=2c4f9d9bb3452e8d79bcba6fc501fe5a882830c409930e807fb81e5c39eb6c1c
#   Stored in directory: /root/.cache/pip/wheels/5c/4b/ec/41f4e116c8053c3654e2c2a47c62b4fca34cc67ef7b55deb7f
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
pip install --user -U nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)

# %%
import pandas as pd
import os
import gensim
import spacy
import en_core_web_sm
import nltk
import math
nltk.download('stopwords')
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))

nlp = en_core_web_sm.load()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df = pd.read_csv('2560+2564.csv',dtype={1:'string'},encoding='TIS-620')
df
# Out:
#       id subject_id                               subject_name_thai  \
# 0      0   01006030                                      แคลคูลัส 1
# 1      1   01006031                                      แคลคูลัส 2
# 2      2   01006032          สมการอนุพันธ์และพีชคณิตเชิงเส้นพื้นฐาน
# 3      3   01006004                            การฝึกงานอุตสาหกรรม
# 4      4   01006028                    เตรียมความพร้อมสําหรับวิศวกร
# ..   ...        ...                                             ...
# 146  146   01076584                     การจำลองระบบด้วยคอมพิวเตอร์
# 147  147   01076592                           ผู้ประกอบการกับวิศวกร
# 148  148   01076422  การประกอบการและการจัดการด้านเทคโนโลยีสารสนเทศ
# 149  149   01076423      การวางแผนเชิงกลยุทธ์โดยใช้บอร์ดและการ์ดเกม
# 150  150   01076577              การจัดการโครงการเทคโนโลยีสารสนเทศ
#
#                                       subject_name_eng  \
# 0                                           CALCULUS 1
# 1                                           CALCULUS 2
# 2    ELEMENTARY DIFFERENTIAL EQUATIONS AND LINEAR A...
# 3                                  INDUSTRIAL TRAINING
# 4                              PRE-ENGINEER ACTIVITIES
# ..                                                 ...
# 146                                COMPUTER SIMULATION
# 147                  ENTREPRENEURSHIP AND THE ENGINEER
# 148                 IT ENTREPRENEURSHIP AND MANAGEMENT
# 149       STRATEGIC PLANNING USING BOARD AND CARD GAME
# 150                              IT PROJECT MANAGEMENT
#
#                                               abstract  \
# 0    Function, Limit, Continuity and their applicat...
# 1    Functions of several variables and theirs appl...
# 2    Systems of linear equations and solutions. vec...
# 3    During their four-year selected studies, stude...
# 4    Participates in activities organized by the Fa...
# ..                                                 ...
# 146  Modeling and simulation; continuous and discre...
# 147  Discusses basic concepts of marketing, busines...
# 148  This course covers the basic of IT entrepreneu...
# 149  This course covers the strategic planning, stu...
# 150  Meaning of Project; Importance of information ...
#
#                  subject_key subject_type  year  subject_class
# 0                        NaN   คณิตศาสตร์  2560            NaN
# 1                        NaN   คณิตศาสตร์  2560            NaN
# 2                        NaN   คณิตศาสตร์  2560            NaN
# 3                        NaN     เลือกภาค  2560            NaN
# 4                        NaN     เลือกภาค  2560            NaN
# ..                       ...          ...   ...            ...
# 146  โครงสร้างพื้นฐานของระบบ     เลือกภาค  2564            NaN
# 147             วิชาบูรณาการ     เลือกภาค  2564            NaN
# 148             วิชาบูรณาการ     เลือกภาค  2564            NaN
# 149             วิชาบูรณาการ     เลือกภาค  2564            NaN
# 150             วิชาบูรณาการ     เลือกภาค  2564            NaN
#
# [151 rows x 9 columns]

# %%
for sentence in df['abstract']:
  newsentence = sentence
  listnewsentence = []
  for i in newsentence.split():
    i = i.replace(';',"")
    i = i.replace(',',"")
    listnewsentence.append(i)
  newsentence = set(listnewsentence) - set(STOPWORDS)   
  newsentence = " ".join(list(newsentence))
  df = df.replace({'abstract': sentence}, {'abstract': newsentence}, regex=True)
df
# Out:
#       id subject_id                               subject_name_thai  \
# 0      0   01006030                                      แคลคูลัส 1
# 1      1   01006031                                      แคลคูลัส 2
# 2      2   01006032          สมการอนุพันธ์และพีชคณิตเชิงเส้นพื้นฐาน
# 3      3   01006004                            การฝึกงานอุตสาหกรรม
# 4      4   01006028                    เตรียมความพร้อมสําหรับวิศวกร
# ..   ...        ...                                             ...
# 146  146   01076584                     การจำลองระบบด้วยคอมพิวเตอร์
# 147  147   01076592                           ผู้ประกอบการกับวิศวกร
# 148  148   01076422  การประกอบการและการจัดการด้านเทคโนโลยีสารสนเทศ
# 149  149   01076423      การวางแผนเชิงกลยุทธ์โดยใช้บอร์ดและการ์ดเกม
# 150  150   01076577              การจัดการโครงการเทคโนโลยีสารสนเทศ
#
#                                       subject_name_eng  \
# 0                                           CALCULUS 1
# 1                                           CALCULUS 2
# 2    ELEMENTARY DIFFERENTIAL EQUATIONS AND LINEAR A...
# 3                                  INDUSTRIAL TRAINING
# 4                              PRE-ENGINEER ACTIVITIES
# ..                                                 ...
# 146                                COMPUTER SIMULATION
# 147                  ENTREPRENEURSHIP AND THE ENGINEER
# 148                 IT ENTREPRENEURSHIP AND MANAGEMENT
# 149       STRATEGIC PLANNING USING BOARD AND CARD GAME
# 150                              IT PROJECT MANAGEMENT
#
#                                               abstract  \
# 0    Antiderivative Improper Mathematical Applicati...
# 1    coordinates variables theorem surfaces integra...
# 2    bases orthonormal complex ordinary function So...
# 3    required written This responsibility students ...
# 4    organized technology preparing advising educat...
# ..                                                 ...
# 146  Modeling languages simulation verification mod...
# 147  management bringing planning market success es...
# 148  management planning presentation Art Technolog...
# 149  demonstrate Rules planning covers improvement ...
# 150  management information procurement project tim...
#
#                  subject_key subject_type  year  subject_class
# 0                        NaN   คณิตศาสตร์  2560            NaN
# 1                        NaN   คณิตศาสตร์  2560            NaN
# 2                        NaN   คณิตศาสตร์  2560            NaN
# 3                        NaN     เลือกภาค  2560            NaN
# 4                        NaN     เลือกภาค  2560            NaN
# ..                       ...          ...   ...            ...
# 146  โครงสร้างพื้นฐานของระบบ     เลือกภาค  2564            NaN
# 147             วิชาบูรณาการ     เลือกภาค  2564            NaN
# 148             วิชาบูรณาการ     เลือกภาค  2564            NaN
# 149             วิชาบูรณาการ     เลือกภาค  2564            NaN
# 150             วิชาบูรณาการ     เลือกภาค  2564            NaN
#
# [151 rows x 9 columns]

# %%
thisdict = {}
all_docs = [nlp(row) for row in df['abstract']]
num = 0
for i in range(len(all_docs)):
  check = 0
  sims = []
  if list(thisdict.keys()) == []:
    thisdict[num] = [df.loc[df['id'] == i, 'subject_id'].iloc[0]]
    num += 1
  else:
    for x in thisdict:
      temp = df.loc[df['subject_id'] == thisdict[x][0], 'abstract'].iloc[0]
      sim = all_docs[i].similarity(nlp(temp))
      sims.append(sim)
    maxsim = max(sims)
    for x in thisdict:
      temp = df.loc[df['subject_id'] == thisdict[x][0], 'abstract'].iloc[0]
      sim = all_docs[i].similarity(nlp(temp))
      if sim >= 0.87 and sim == maxsim:
        thisdict[x].append(df.loc[df['id'] == i, 'subject_id'].iloc[0])
        check = 1
        break
    if check != 1:
      thisdict[num] = [df.loc[df['id'] == i, 'subject_id'].iloc[0]]
      num += 1
print(thisdict)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
# {0: ['01006030', '01006031', '01076012', '01076263', '01076021', '01076028', '01076564', '01076591', '01076574', '01076585', '01076567', '01076140', '01076042', '01076043', '01076044', '01076513', '01076564', '01076574', '01076585', '01076567'], 1: ['01006032', '01076010', '01076614', '01076141 ', '01076032', '01076116', '01076117'], 2: ['01006004', '01006004'], 3: ['01006028', '01076253', '01076002', '01076004', '01076007', '01076023', '01076421', '01076253', '01076103 ', '01076104', '01076421', '01076635', '01076423'], 4: ['01076003', '01076107'], 5: ['01076001', '01076024', '01076005', '01076101', '01076559'], 6: ['01076005', '01076109', '01076110 '], 7: ['01076006', '01076009', '01076561 ', '01076112', '01076113', '01076114', '01076115'], 8: ['01076008', '01076013', '01076411', '01076568', '01076589', '01076566', '01076597', '01076582', '01076628', '01076121', '01076034', '01076035 ', '01076411', '01076568', '01076566', '01076597', '01076582', '01076628', '01076577'], 9: ['01076011', '01076029', '01076630', '01076632', '01076633', '01076011', '01076632'], 10: ['01076014', '01076016'], 11: ['01076015'], 12: ['01076022', '01076513', '01076012', '01076050', '01076051', '01076414'], 13: ['01076025', '01076119', '01076120'], 14: ['01076026', '01076584', '01076036', '01076037', '01076584'], 15: ['01076027', '01076532', '01076040', '01076041', '01076532'], 16: ['01076311', '01076312', '01076629', '01076311', '01076312', '01076560', '01076629'], 17: ['01076029', '01076118'], 18: ['01076418', '01076418'], 19: ['01076419', '01076053'], 20: ['01076420'], 21: ['01076595', '01076105', '01076106', '01076599', '01076636'], 22: ['01076596', '01076596'], 23: ['01076634', '01076634'], 24: ['01076598 ', '01076598'], 25: ['01076583', '01076589', '01076583', '01076422'], 26: ['01076595'], 27: ['01076627', '01076263 ', '01076627', '01076592'], 28: ['01076631', '01076631'], 29: ['01076108'], 30: ['01076052'], 31: ['01006029'], 32: ['01006005'], 33: ['01076420'], 34: ['01076558'], 35: ['01076533'], 36: ['01076595']}
